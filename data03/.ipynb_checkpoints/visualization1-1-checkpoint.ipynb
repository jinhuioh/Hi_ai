# %%
import numpy as np
import pandas as pd

# %%
teen = pd.read_excel('../csv-data/teenage_mental.xls')
teen
# Out:
#      기간  구분  스트레스 인지율 스트레스 인지율.1 스트레스 인지율.2 우울감 경험률 우울감 경험률.1 우울감 경험률.2  \
# 0    기간  구분        전체        남학생        여학생      전체       남학생       여학생
# 1  2018   구분     42.7       34.5       51.5    29.6      24.2      35.4
#
#   자살 생각률 자살 생각률.1 자살 생각률.2
# 0     전체      남학생      여학생
# 1   15.4     11.8     19.2

# %%
teen = pd.read_excel('../csv-data/teenage_mental.xls',header=1#header = 1은 1번째 인덱스의 행부터 가져오겠다는 의미.
                    ,usecols='C:K')#usecols='C:K' C부터K까지만 값 가져오기.
teen
# Out:
#      전체   남학생   여학생  전체.1  남학생.1  여학생.1  전체.2  남학생.2  여학생.2
# 0  42.7  34.5  51.5  29.6   24.2   35.4  15.4   11.8   19.2

# %%
teen = pd.read_excel('../csv-data/teenage_mental.xls'
                    ,usecols='C:K')#usecols='C:K' C부터K까지만 값 가져오기.
teen
# Out:
#   스트레스 인지율 스트레스 인지율.1 스트레스 인지율.2 우울감 경험률 우울감 경험률.1 우울감 경험률.2 자살 생각률 자살 생각률.1  \
# 0       전체        남학생        여학생      전체       남학생       여학생     전체      남학생
# 1     42.7       34.5       51.5    29.6      24.2      35.4   15.4     11.8
#
#   자살 생각률.2
# 0      여학생
# 1     19.2

# %%
teen.loc[2] = 100 - teen.loc[1]
teen
# Out:
#   스트레스 인지율 스트레스 인지율.1 스트레스 인지율.2 우울감 경험률 우울감 경험률.1 우울감 경험률.2 자살 생각률 자살 생각률.1  \
# 0       전체        남학생        여학생      전체       남학생       여학생     전체      남학생
# 1     42.7       34.5       51.5    29.6      24.2      35.4   15.4     11.8
# 2     57.3       65.5       48.5    70.4      75.8      64.6   84.6     88.2
#
#   자살 생각률.2
# 0      여학생
# 1     19.2
# 2     80.8

# %%
col_names = ['스트레스전체','스트레스남학생','스트레스여학생',
             '우울전체','우울남학생','우울여학생',
            '자살전체','자살남학생','자살여학생']

# %%
teen = pd.read_excel('../csv-data/teenage_mental.xls',header=1#header = 1은 1번째 인덱스의 행부터 가져오겠다는 의미.
                    ,usecols='C:K', names = col_names)#usecols='C:K' C부터K까지만 값 가져오기.
teen
# Out:
#    스트레스전체  스트레스남학생  스트레스여학생  우울전체  우울남학생  우울여학생  자살전체  자살남학생  자살여학생
# 0    42.7     34.5     51.5  29.6   24.2   35.4  15.4   11.8   19.2

# %%
teen.loc[1] = 100 - teen.loc[0]
teen
# Out:
#    스트레스전체  스트레스남학생  스트레스여학생  우울전체  우울남학생  우울여학생  자살전체  자살남학생  자살여학생
# 0    42.7     34.5     51.5  29.6   24.2   35.4  15.4   11.8   19.2
# 1    57.3     65.5     48.5  70.4   75.8   64.6  84.6   88.2   80.8

# %%
teen['응답'] = ['그렇다','아니다']
teen
# Out:
#      스트레스전체  스트레스남학생  스트레스여학생  우울전체  우울남학생  우울여학생  자살전체  자살남학생  자살여학생   응답
# 응답
# 그렇다    42.7     34.5     51.5  29.6   24.2   35.4  15.4   11.8   19.2  그렇다
# 아니다    57.3     65.5     48.5  70.4   75.8   64.6  84.6   88.2   80.8  아니다

# %%
teen.set_index('응답',inplace = True)
teen
# Out:
#      스트레스전체  스트레스남학생  스트레스여학생  우울전체  우울남학생  우울여학생  자살전체  자살남학생  자살여학생
# 응답
# 그렇다    42.7     34.5     51.5  29.6   24.2   35.4  15.4   11.8   19.2
# 아니다    57.3     65.5     48.5  70.4   75.8   64.6  84.6   88.2   80.8

# %%
import matplotlib.pyplot as plt
#이거 임포트 해줘야 차트에서 오류안남!!! 한글파일때문에 오류나는거.
from matplotlib import rc, font_manager
import matplotlib.font_manager as fm

# 디렉토리 및 파일 이름에 맞추어 변경
font_location = 'C:/Windows/Fonts/malgun.ttf'#윈도우안에있는 폰트파일주소.
#font_location = '../NanumGothic.ttf'

font_name = fm.FontProperties(fname=font_location).get_name()
rc('font', family=font_name)

# %%
teen['스트레스전체'].plot.pie(autopct = '%1.1f%%')#autopct = '%1.1f%%'를 써야퍼센트가 나옴.
# Out:
# <AxesSubplot:ylabel='스트레스전체'>
