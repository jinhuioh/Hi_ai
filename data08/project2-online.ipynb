# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings(action='ignore')#임포트 해주면 그래프 그릴때 무시해도 되는 오류 안뜸!

# %%
#2018~2020.4월까지 인터넷 이용자 비율을 나이로 구분한 데이터
onlineData = pd.read_excel('../csv-data/인터넷_쇼핑_성_연령별__20220327012037.xlsx')
onlineData.head(11)
# #행과 열을 한정해서 일부만 가져와보자.
# onlineData = pd.read_excel('cctv_data_collect/pop_seoul.xls',
#                          header = 2,
#                          usecols='B,D,G,J,N'
#                          )
# onlineData.head()#header = 2 번 인덱스 행부터 가져옴.
# Out:
#     성별(1)  연령별(1)               2018               2018.1  \
# 0   성별(1)  연령별(1)  인터넷 쇼핑 이용자 비율 (%)  월 평균 구매빈도-1회 미만 (%)
# 1      전체      전체               62.0                 15.3
# 2     NaN  12-19세               55.7                 16.1
# 3     NaN     20대               96.4                 12.1
# 4     NaN     30대               91.3                 12.6
# 5     NaN     40대               71.4                 16.2
# 6     NaN     50대               40.0                 23.1
# 7     NaN     60대               17.5                 22.3
# 8     NaN  70세 이상               11.2                 10.6
# 9      여자      전체               63.8                 14.1
# 10    NaN  12-19세               59.0                 14.4
#
#                    2018.2                 2018.3               2018.4  \
# 0   월 평균 구매빈도-1~2회 미만 (%)  월 평균 구매빈도-2~3회 미만 (%)  월 평균 구매빈도-3회 이상 (%)
# 1                    20.5                   19.9                 44.3
# ...

# %% [markdown]
# #년도별로 짤라서 전체 구매율의 빈도, 월별 비율을 보고,쇼핑몰 창업이 괜찮은지 그래프 그려보기.
# #년도별 나이에 대한 이용자 비율을 그래프로 그려보기.
# #어느 나이대가 구매 빈도가 높은지 나이별로 그래프 그려보기.
# #이용자 비울에 대한 구매율이 나이대로 어떤지 그래프 그려보기.
# #월 별, 구매율이 높은 달이 있는지 그래프로 그려보기.

# %%
onlineData_2018 = onlineData.iloc[:,:8]
onlineData_2018.head()
# Out:
#    성별(1)  연령별(1)               2018               2018.1  \
# 0  성별(1)  연령별(1)  인터넷 쇼핑 이용자 비율 (%)  월 평균 구매빈도-1회 미만 (%)
# 1     전체      전체               62.0                 15.3
# 2    NaN  12-19세               55.7                 16.1
# 3    NaN     20대               96.4                 12.1
# 4    NaN     30대               91.3                 12.6
#
#                   2018.2                 2018.3               2018.4  \
# 0  월 평균 구매빈도-1~2회 미만 (%)  월 평균 구매빈도-2~3회 미만 (%)  월 평균 구매빈도-3회 이상 (%)
# 1                   20.5                   19.9                 44.3
# 2                   21.7                   15.5                 46.7
# 3                   19.6                   22.4                 45.9
# 4                   19.1                   21.9                 46.4
#
#              2018.5
# 0  월 평균 구매빈도-평균 (회)
# 1               3.0
# 2               2.6
# 3               3.1
# 4               3.3

# %%
onlineData_2018.drop(columns=['성별(1)','연령별(1)'],inplace=True)
onlineData_2018.tail()
# Out:
#     2018 2018.1 2018.2 2018.3 2018.4 2018.5
# 20  86.3   14.6   21.3   22.4   41.7    2.9
# 21  66.8   17.1   23.2   20.0   39.7    2.9
# 22  39.0   23.5   21.2   14.6   40.7    2.5
# 23  20.3   20.8   21.4   12.3   45.4    3.2
# 24  13.8   11.4   10.5    8.3   69.8    3.6

# %%
onlineData_2018.drop(columns=['2018'],inplace=True)#구매비율만 컬럼에 넣음.
onlineData_2018.tail()
# Out:
#    2018.1 2018.2 2018.3 2018.4 2018.5
# 20   14.6   21.3   22.4   41.7    2.9
# 21   17.1   23.2   20.0   39.7    2.9
# 22   23.5   21.2   14.6   40.7    2.5
# 23   20.8   21.4   12.3   45.4    3.2
# 24   11.4   10.5    8.3   69.8    3.6

# %%
onlineData_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   2018.1  25 non-null     object
#  1   2018.2  25 non-null     object
#  2   2018.3  25 non-null     object
#  3   2018.4  25 non-null     object
#  4   2018.5  25 non-null     object
# dtypes: object(5)
# memory usage: 1.1+ KB

# %%
onlineData_2018.head()
# Out:
#    index  구매빈도 1회미만  구매빈도 1~2회미만  구매빈도 2~3회미만  구매빈도 3회이상  2018년 월평균 구매빈도
# 0      1       15.3         20.5         19.9       44.3             3.0
# 1      2       16.1         21.7         15.5       46.7             2.6
# 2      3       12.1         19.6         22.4       45.9             3.1
# 3      4       12.6         19.1         21.9       46.4             3.3
# 4      5       16.2         21.0         20.2       42.6             3.1

# %%
onlineData_2018.isnull().sum()#데이터에 빈 값이 있는지 확인.
# Out:
# 2018.1    0
# 2018.2    0
# 2018.3    0
# 2018.4    0
# 2018.5    0
# dtype: int64

# %%
onlineData_2018.head()
# Out:
#                 2018.1                 2018.2                 2018.3  \
# 0  월 평균 구매빈도-1회 미만 (%)  월 평균 구매빈도-1~2회 미만 (%)  월 평균 구매빈도-2~3회 미만 (%)
# 1                 15.3                   20.5                   19.9
# 2                 16.1                   21.7                   15.5
# 3                 12.1                   19.6                   22.4
# 4                 12.6                   19.1                   21.9
#
#                 2018.4            2018.5
# 0  월 평균 구매빈도-3회 이상 (%)  월 평균 구매빈도-평균 (회)
# 1                 44.3               3.0
# 2                 46.7               2.6
# 3                 45.9               3.1
# 4                 46.4               3.3

# %%
onlineData_2018.drop(index=[0],inplace=True)
onlineData_2018.head()
# Out:
#   2018.1 2018.2 2018.3 2018.4 2018.5
# 1   15.3   20.5   19.9   44.3    3.0
# 2   16.1   21.7   15.5   46.7    2.6
# 3   12.1   19.6   22.4   45.9    3.1
# 4   12.6   19.1   21.9   46.4    3.3
# 5   16.2   21.0   20.2   42.6    3.1

# %%
# onlineData_2018.astype('float')
# onlineData_2018.reset_index(inplace=True)
#행의 타입 변경해야함.

# %%
onlineData_2018.rename(columns={'2018.1':'구매빈도 1회미만','2018.2':'구매빈도 1~2회미만','2018.3':'구매빈도 2~3회미만',
                                '2018.4':'구매빈도 3회이상','2018.5':'2018년 월평균 구매빈도'},inplace=True)
onlineData_2018.head()
# Out:
#    index 구매빈도 1회미만 구매빈도 1~2회미만 구매빈도 2~3회미만 구매빈도 3회이상 2018년 월평균 구매빈도
# 0      1      15.3        20.5        19.9      44.3            3.0
# 1      2      16.1        21.7        15.5      46.7            2.6
# 2      3      12.1        19.6        22.4      45.9            3.1
# 3      4      12.6        19.1        21.9      46.4            3.3
# 4      5      16.2        21.0        20.2      42.6            3.1

# %%
#각 월에 대한 구매율의 평균을 df로 표현해보자.
#구매율과 구매비율의 월에 따른 상관도를 그려보자.
onlineData_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   index           24 non-null     int64
#  1   구매빈도 1회미만       24 non-null     object
#  2   구매빈도 1~2회미만     24 non-null     object
#  3   구매빈도 2~3회미만     24 non-null     object
#  4   구매빈도 3회이상       24 non-null     object
#  5   2018년 월평균 구매빈도  24 non-null     object
# dtypes: int64(1), object(5)
# memory usage: 1.2+ KB

# %%
onlineData_2018 = onlineData_2018.astype({'구매빈도 1회미만':'float'})
onlineData_2018.head()
# Out:
#    index  구매빈도 1회미만 구매빈도 1~2회미만 구매빈도 2~3회미만 구매빈도 3회이상 2018년 월평균 구매빈도
# 0      1       15.3        20.5        19.9      44.3            3.0
# 1      2       16.1        21.7        15.5      46.7            2.6
# 2      3       12.1        19.6        22.4      45.9            3.1
# 3      4       12.6        19.1        21.9      46.4            3.3
# 4      5       16.2        21.0        20.2      42.6            3.1

# %%
onlineData_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   index           24 non-null     int64
#  1   구매빈도 1회미만       24 non-null     float64
#  2   구매빈도 1~2회미만     24 non-null     object
#  3   구매빈도 2~3회미만     24 non-null     object
#  4   구매빈도 3회이상       24 non-null     object
#  5   2018년 월평균 구매빈도  24 non-null     object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 1.2+ KB

# %%
onlineData_2018 = onlineData_2018.astype({'구매빈도 1~2회미만':'float','구매빈도 2~3회미만':'float',
                                          '구매빈도 3회이상':'float','2018년 월평균 구매빈도':'float'})
onlineData_2018.head()
# Out:
#    index  구매빈도 1회미만  구매빈도 1~2회미만  구매빈도 2~3회미만  구매빈도 3회이상  2018년 월평균 구매빈도
# 0      1       15.3         20.5         19.9       44.3             3.0
# 1      2       16.1         21.7         15.5       46.7             2.6
# 2      3       12.1         19.6         22.4       45.9             3.1
# 3      4       12.6         19.1         21.9       46.4             3.3
# 4      5       16.2         21.0         20.2       42.6             3.1

# %%
onlineData_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   index           24 non-null     int64
#  1   구매빈도 1회미만       24 non-null     float64
#  2   구매빈도 1~2회미만     24 non-null     float64
#  3   구매빈도 2~3회미만     24 non-null     float64
#  4   구매빈도 3회이상       24 non-null     float64
#  5   2018년 월평균 구매빈도  24 non-null     float64
# dtypes: float64(5), int64(1)
# memory usage: 1.2 KB

# %%
#월 평균 구매 빈도를 바 그래프로 그려보자.
#2018년
onlineData_2018['2018년 월평균 구매빈도'].value_counts().mean()
# Out:
# 2.4

# %%
onlineData_2019 = onlineData.iloc[:,13:14]
onlineData_2019.head()
# Out:
#              2019.5
# 0  월 평균 구매빈도-평균 (회)
# 1               3.3
# 2               2.8
# 3               3.5
# 4               3.3

# %%
onlineData_2020 = onlineData.iloc[:,19:20]
onlineData_2020.head()
# Out:
#              2020.5
# 0  월 평균 구매빈도-평균 (회)
# 1               5.0
# 2               4.0
# 3               5.2
# 4               5.7

# %%
onlineData_2019.drop(index=[0],inplace=True)
onlineData_2019.head()
# Out:
#   2019.5
# 1    3.3
# 2    2.8
# 3    3.5
# 4    3.3
# 5    3.4

# %%
onlineData_2019 = onlineData_2019.astype({'2019.5':'float'})
onlineData_2019.head()
onlineData_2019_1 = onlineData_2019.rename(columns={'2019.5':'2019년 월평균 구매빈도'})
onlineData_2019_1.head()
# Out:
#    2019년 월평균 구매빈도
# 1             3.3
# 2             2.8
# 3             3.5
# 4             3.3
# 5             3.4

# %%
 onlineData_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24 entries, 1 to 24
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   2019.5  24 non-null     float64
# dtypes: float64(1)
# memory usage: 384.0 bytes

# %%
onlineData_2020.drop(index=[0],inplace=True)
onlineData_2020.head()
# Out:
#   2020.5
# 1    5.0
# 2    4.0
# 3    5.2
# 4    5.7
# 5    5.3

# %%
onlineData_2020 = onlineData_2020.astype({'2020.5':'float'})
onlineData_2020.head()
onlineData_2020_1 = onlineData_2020.rename(columns={'2020.5':'2020년 월평균 구매빈도'})
onlineData_2020_1.head()
# Out:
#    2020년 월평균 구매빈도
# 1             5.0
# 2             4.0
# 3             5.2
# 4             5.7
# 5             5.3

# %%
onlineData_2018_1 = onlineData_2018.iloc[:,5:6]
onlineData_2018_1.head()
# Out:
#    2018년 월평균 구매빈도
# 0             3.0
# 1             2.6
# 2             3.1
# 3             3.3
# 4             3.1

# %%
#머지(merge) 함수를 사용해서 데이터프레임 합치기
# onlineData_mean = pd.merge(cctv_seoul,pop_seoul,on='구별')
# data_result.head()

# %%
onlineData_2018_mean = onlineData_2018_1.value_counts().mean()
print(onlineData_2018_mean)
onlineData_2019_mean = onlineData_2019_1.value_counts().mean()
print(onlineData_2019_mean)
onlineData_2020_mean = onlineData_2020_1.value_counts().mean()
print(onlineData_2020_mean)
# Out:
# 2.4
# 1.8461538461538463
# 1.7142857142857142

# %%
# 월평균 구매 빈도 그래프를 그려보자.
x = ['2018년 월평균 구매빈도', '2019년 월평균 구매빈도', '2020년 월평균 구매빈도']
y = [2.4, 1.8461538461538463, 1.7142857142857142]

# %%
onlineData_mean = pd.DataFrame({'' : x, 'weight' : y}, index=x)
onlineData_mean
