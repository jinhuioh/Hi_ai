# %%
# Python3 샘플 코드 #
import requests
#시약
url = 'http://apis.data.go.kr/1471000/CovidDagnsRgntProdExprtStusService/getCovidDagnsRgntProdExprtStusInq'
params ={'serviceKey' : '9QJcKmLfZag2pqpAKguul6SFur5rfw0X5IO4rNzZHxoWY4HsUH2YKyb3zNJhV1z8mQRNDAXH5qFkqKD83U3Qrg==', 'pageNo' : '1', 'numOfRows' : '3', 'type' : 'json', 'YYYY' : '2020', 'MM' : '12' }
#공공api사이트에서 일반인증키:디코딩키로 넣음.
response = requests.get(url, params=params)
print(response.content)
# Out:
# b'{"header":{"resultCode":"00","resultMsg":"NORMAL SERVICE."},"body":{"pageNo":1,"totalCount":1,"numOfRows":3,"items":[{"YYYY":"2020","MM":"12","KIT_PROD_QTY":"8,037,499","KIT_EXPRT_QTY":"7,770,134","KIT_STOCK_QTY":"12,027,702"}]}}'

# %%
# #언론재단
# #https://api.odcloud.kr/api/15069309/v1/uddi:973ad0df-617a-4565-8e82-8ea7869e75d4?page=1&perPage=10&serviceKey=9QJcKmLfZag2pqpAKguul6SFur5rfw0X5IO4rNzZHxoWY4HsUH2YKyb3zNJhV1z8mQRNDAXH5qFkqKD83U3Qrg%253D%253D

# %%
import requests
## decode key가 적용되었음.
## api마다 연결이 되지 않는다고 한다면, encode, decode를 바꾸어 테스트해볼 것.
headers_data = {
    'accept': 'application/json',
    'Authorization': '9QJcKmLfZag2pqpAKguul6SFur5rfw0X5IO4rNzZHxoWY4HsUH2YKyb3zNJhV1z8mQRNDAXH5qFkqKD83U3Qrg%3D%3D',
}

params_data = (
    ('page', '1'),
    ('perPage', '2'),
    ('serviceKey', '9QJcKmLfZag2pqpAKguul6SFur5rfw0X5IO4rNzZHxoWY4HsUH2YKyb3zNJhV1z8mQRNDAXH5qFkqKD83U3Qrg=='),
)
url = 'https://api.odcloud.kr/api/15069309/v1/uddi:973ad0df-617a-4565-8e82-8ea7869e75d4'

# https://api.odcloud.kr/api/15069309/v1/uddi:973ad0df-617a-4565-8e82-8ea7869e75d4? #여기까지가 url
#         page=1&perPage=2&
#         serviceKey=9QJcKmLfZag2pqpAKguul6SFur5rfw0X5IO4rNzZHxoWY4HsUH2YKyb3zNJhV1z8mQRNDAXH5qFkqKD83U3Qrg%253D%253D

        
# curl -X GET "https://api.odcloud.kr/api/15069309/v1/uddi:973ad0df-617a-4565-8e82-8ea7869e75d4?page=1&perPage=2&serviceKey=9QJcKmLfZag2pqpAKguul6SFur5rfw0X5IO4rNzZHxoWY4HsUH2YKyb3zNJhV1z8mQRNDAXH5qFkqKD83U3Qrg%253D%253D"
# -H  "accept: application/json"
# -H  "Authorization: 9QJcKmLfZag2pqpAKguul6SFur5rfw0X5IO4rNzZHxoWY4HsUH2YKyb3zNJhV1z8mQRNDAXH5qFkqKD83U3Qrg%3D%3D"
## decode key가 적용되었음.
## api마다 연결이 되지 않는다고 한다면, encode, decode를 바꾸어 테스트해볼 것.
response = requests.get(url, headers=headers_data, params=params_data)
response
# Out:
# <Response [200]>

# %%
import requests

header_data= {
    'accept': 'application/json',
    'Authorization': 'VXgWV/f5wELzapZjJF7FEqqtFhPbNA8KBIWia3SXOCvY+CXEUok1DhybfbP4USE/g2b/QYT62C2mw3zcSWj2pg==',
}

param_data = (
    ('page', '1'),
    ('perPage', '2'),
    ('serviceKey', 'VXgWV/f5wELzapZjJF7FEqqtFhPbNA8KBIWia3SXOCvY+CXEUok1DhybfbP4USE/g2b/QYT62C2mw3zcSWj2pg=='),
)

url = 'https://api.odcloud.kr/api/15069309/v1/uddi:973ad0df-617a-4565-8e82-8ea7869e75d4'
## decode key가 적용되었음.
## api마다 연결이 되지 않는다고 한다면, encode, decode를 바꾸어 테스트해볼 것.
response = requests.get(url, headers=header_data, params=param_data)
response
# Out:
# {'swagger': '2.0',
#  'info': {'version': '1',
#   'title': '한국언론진흥재단_뉴스빅데이터_메타데이터_코로나',
#   'description': '2월~8월까지 월간 데이터를 순차적으로 등록 중입니다. 차기등록예정일은 익월로 변경하고자 하오니 참고하여 주시기 바랍니다.'},
#  'host': 'api.odcloud.kr',
#  'basePath': '/api',
#  'schemes': ['https', 'http'],
#  'securityDefinitions': {'ApiKeyAuth': {'type': 'apiKey',
#    'in': 'header',
#    'name': 'Authorization'},
#   'ApiKeyAuth2': {'type': 'apiKey', 'in': 'query', 'name': 'serviceKey'}},
#  'paths': {'/15069309/v1/uddi:973ad0df-617a-4565-8e82-8ea7869e75d4': {'get': {'tags': ['API 목록'],
#     'summary': '',
#     'operationId': 'GETuddi:973ad0df-617a-4565-8e82-8ea7869e75d4',
#     'description': '한국언론진흥재단_뉴스빅데이터_메타데이터_코로나_20200229',
#     'consumes': ['application/json'],
#     'produces': ['application/json'],
#     'parameters': [{'name': 'page',
#       'in': 'query',
#       'description': 'page index',
#       'type': 'integer',
#       'format': 'int64',
#       'exclusiveMinimum': False,
#       'default': 1},
# ...

# %%
#수자원
url = 'http://apis.data.go.kr/B500001/myportal/travel/travellist'
params ={'serviceKey' : '9QJcKmLfZag2pqpAKguul6SFur5rfw0X5IO4rNzZHxoWY4HsUH2YKyb3zNJhV1z8mQRNDAXH5qFkqKD83U3Qrg==', 'pageNo' : '1', 'numOfRows' : '10', 'searchTypeCd' : '01', 'regionCd' : 'HA', '_type' : 'json' }

response = requests.get(url, params=params)
print(response.content)
response
# Out:
# b'{"response":{"header":{"resultCode":"00","resultMsg":"NORMAL SERVICE."},"body":{"items":{"item":[{"course":"\xec\x9e\x90\xeb\x9d\xbc\xec\x84\xac\xec\x98\xa4\xed\x86\xa0\xec\xba\xa0\xed\x95\x91\xec\x9e\xa5 - \xed\x98\xb8\xeb\xaa\x85\xed\x98\xb8\xec\x88\x98\xea\xb3\xb5\xec\x9b\x90 - \xec\x81\x98\xeb\x9d\xa0\xed\x94\x84\xeb\x9e\x91\xec\x8a\xa4(La Petite France) - \xea\xb0\x95\xec\xb4\x8c\xec\x9c\xa0\xec\x9b\x90\xec\xa7\x80 - \xea\xb9\x80\xec\x9c\xa0\xec\xa0\x95 \xeb\xac\xb8\xed\x95\x99\xec\xb4\x8c","intro":"\xea\xb0\x80\xec\xa1\xb1 \xeb\x8b\xa8\xec\x9c\x84 \xec\xba\xa0\xed\x95\x91\xec\x9d\xb4 \xeb\x8a\x98\xeb\xa9\xb4\xec\x84\x9c \xec\xba\xa0\xed\x95\x91\xec\x9e\xa5\xec\x97\x90\xeb\x8f\x84 \xeb\xa7\x8e\xec\x9d\x80 \xeb\xb3\x80\xed\x99\x94\xea\xb0\x80 \xec\x83\x9d\xea\xb8\xb0\xea\xb3\xa0 \xec\x9e\x88\xeb\x8b\xa4. \xeb\x8b\xa8\xec\x88\x9c\xed\x9e\x88 \xec\xba\xa0\xed\x95\x91 \xec\x82\xac\xec\x9d\xb4\xed\x8a\xb8\xeb\xa5\xbc \xec\xa0\x9c\xea\xb3\xb5\xed\x95\x98\xeb\x8d\x98 \xeb\x8d\xb0\xec
# ...
