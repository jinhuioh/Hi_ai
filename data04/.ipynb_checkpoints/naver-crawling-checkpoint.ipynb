# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
client_id = "U4P7qzPKkU7dtADYoa1Q"
client_secret = "jdrEqbks3s"
encText = urllib.parse.quote("자동차")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# "lastBuildDate": "Mon, 21 Mar 2022 17:45:55 +0900",
# "total": 778935,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "grep은 <b>검색</b> 패턴과 일치하는 <b>단어</b>만 표시할 수 있습니까?",
# "link": "https:\/\/blog.naver.com\/peloozoid116286?Redirect=Log&logNo=222674657295",
# "description": "txt apple apple- apple-fruit fruit-apple &quot;icon-&quot;으로 시작하는 모든 단어를 검색하려면 다음... 그러면 <b>검색할 단어</b> 또는 정규식이 무엇입니까? , 당신에게 달려 있습니다! Perl 구문이... ",
# "bloggername": "peloozoid116286님의블로그",
# "bloggerlink": "https://blog.naver.com/peloozoid116286",
# "postdate": "20220316"
#
# },
# {
# "title": "딕셔너리 활용 예제 | 영어 <b>단어</b> <b>검색</b> 프로그램 만들기",
# "link": "https:\/\/blog.naver.com\/codethem?Redirect=Log&logNo=222310806177",
# "description": "아래와 같이 <b>검색할 단어</b>를 입력하면, 검색한 단어의 뜻을 알려줍니다. 그리고 등록되어 있지 않은 단어는 등록되어 있지 않다는 메시지를 띄워줍니다. 함께 코드를 만들어 나가기 전에, 아래 영상을 통해... ",
# "bloggername": "꿈을 코딩하다 CodeThem",
# "bloggerlink": "https://blog.naver.com/codethem",
# "postdate": "20210415"
#
# },
# {
# "title": "블로그 <b>검색</b> 누락 해결 방법 (ft. 중복 <b>단어</b> 빨리 찾는법)",
# "link": "https:\/\/blog.naver.com\/tomatoohj?Redirect=Log&logNo=222663894671",
# "description": "금칙어 사용 내가 의도하지 않았지만 <b>단어</b>만 <b>검색</b>했을 때 욕설이나 음란성, 불법적인 말들이 되었을 때도 슬픈 일이 생기지요 최대한 금지된 <b>단어</b>는 피하는 게 좋아요 나의 글을 깨끗이 만듭시다!!! 블로그... ",
# "bloggername": "Woo_Ri♥아이랑제주",
# "bloggerlink": "https://blog.naver.com/tomatoohj",
# "postdate": "20220304"
#
# },
# {
# "title": "프로그래밍 방식으로 책에서 <b>단어</b>를 <b>검색</b>하는 방법은 무엇입니까?",
# "link": "https:\/\/blog.naver.com\/roinad25939?Redirect=Log&logNo=222662080165",
# "description": "완전한 <b>단어</b>만 <b>검색</b>하시겠습니까, 아니면 <b>단어</b>의 시작 부분도 <b>검색</b>하시겠습니까? 완전한 <b>단어</b>의 경우 간단한 해시 테이블이 아마도 가장 빠를 것입니다. <b>단어</b>의 일부를 찾고 싶다면 접미사 트리를... ",
# "bloggername": "roinad25939님의블로그",
# "bloggerlink": "https://blog.naver.com/roinad25939",
# "postdate": "20220302"
#
# },
# {
# "title": "아이폰 사파리 웹페이지내 텍스트 찾기 <b>단어</b> <b>검색</b> 하는 방법",
# "link": "https:\/\/blog.naver.com\/leodes?Redirect=Log&logNo=222288559042",
# "description": "여기에 원하시는 텍스트를 입력하면 다른 텍스트나 <b>단어</b>도 바로 <b>검색</b> 가능합니다. 4. 사파리에서 <b>검색</b>하고자 하는 <b>단어</b>나 텍스트가 2개 이상이면 이 웹페이지내에 몇개 있는지 2/2이런 방식으로 표시 됩니다.... ",
# "bloggername": "미로아르테 가죽공방",
# "bloggerlink": "https://blog.naver.com/leodes",
# "postdate": "20210326"
#
# },
# {
# "title": "한글 <b>단어</b>찾기, 바꾸기, <b>검색</b>하는 법",
# "link": "https:\/\/blog.naver.com\/toddlfwnwkd?Redirect=Log&logNo=222164657839",
# "description": "발견했으며 노란색으로 표시되는 것을 확인할 수 있습니다. 이번 글에서는 <b>단어</b>찾기, <b>검색</b>, 바꾸는 방법 등에 대해 알아보았습니다! 정보가 도움이 되셨다면 공감과 댓글을! 블로그 주인장에게 큰 힘이 됩니다.",
# "bloggername": "SomeDay..님의 블로그",
# "bloggerlink": "https://blog.naver.com/toddlfwnwkd",
# "postdate": "20201206"
#
# },
# {
# "title": "한글 문서 내용에 있는 <b>단어</b>로 <b>검색</b>하기(한컴, 파워포인트... ",
# "link": "https:\/\/blog.naver.com\/sunder-power?Redirect=Log&logNo=222205710406",
# "description": "그러다보니 그냥 탐색기에서 <b>단어</b>를 <b>검색</b>하다보면 문서의 내용에는 포함되어있지만 제목에 들어가 있지 않아 <b>검색</b>이 안 되는 경우가 종종 있다. 그럼 한글 문서 내용에 있는 <b>단어</b>나 키워드를 <b>검색할</b> 순 없을까?... ",
# "bloggername": "워킹대디",
# "bloggerlink": "https://blog.naver.com/sunder-power",
# "postdate": "20210113"
#
# },
# {
# "title": "［절대 <b>검색</b>하면 안되는 <b>단어</b> -레벨도 6 -］Monoxide.exe",
# "link": "https:\/\/blog.naver.com\/qwsaerfd87?Redirect=Log&logNo=222536175175",
# "description": "설명 【경고】흉악한 바이러스 파일이므로 가상 환경 외에선 실행하지 말 것 이 워드를 <b>검색</b>하면... 이 키워드로 <b>검색할</b> 때 나오는 검증 영상과 실황 영상에선 위의 동작을 실제로 열람하는 것이... ",
# "bloggername": "I Still Think about y",
# "bloggerlink": "https://blog.naver.com/qwsaerfd87",
# "postdate": "20211013"
#
# },
# {
# "title": "네이버에 원하는 <b>단어</b>로 <b>검색</b> 하는 방법",
# "link": "https:\/\/blog.naver.com\/cyul2?Redirect=Log&logNo=222624058318",
# "description": "그외에도 몇퍼센트인지 계산하고 싶을 때 <b>검색</b>창에 '퍼센트 계산기'라고 찾아 활용할 수 있습니다. #퍼센트계산기 <b>검색</b>창에 궁금한 <b>단어</b>를 넣으면 유용한 <b>검색</b>결과를 얻을 수 있다는 것을 알아보았습니다.",
# "bloggername": "호주머니 속 스마트 세상",
# "bloggerlink": "https://blog.naver.com/cyul2",
# "postdate": "20220117"
#
# },
# {
# "title": "PDF <b>단어</b><b>검색</b> 하는방법 총정리",
# "link": "https:\/\/blog.naver.com\/hikayoung?Redirect=Log&logNo=222033675870",
# "description": "출처 : 구글이미지 PDF를 실행 하고 검색 창을 활성화시킨 후 찾는 위치 : 외부 폴더 - 폴더 지정 - <b>검색할 단어</b> 또는 구 선택 - <b>검색할</b> '<b>단어</b>' 또는 '구'를 입력합니다. 예를 들어 단어 블로그를 검색한다고... ",
# "bloggername": "슬기로운블로그탐구생활",
# "bloggerlink": "https://blog.naver.com/hikayoung",
# "postdate": "20200717"
#
# }
# ]
# }
