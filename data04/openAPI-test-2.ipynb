# %%
import requests

header_data= {
    'accept': 'application/json',
    'Authorization': 'VXgWV/f5wELzapZjJF7FEqqtFhPbNA8KBIWia3SXOCvY+CXEUok1DhybfbP4USE/g2b/QYT62C2mw3zcSWj2pg==',
}

param_data = (
    ('page', '1'),
    ('perPage', '10'),
    ('serviceKey', 'VXgWV/f5wELzapZjJF7FEqqtFhPbNA8KBIWia3SXOCvY+CXEUok1DhybfbP4USE/g2b/QYT62C2mw3zcSWj2pg=='),
)

url = 'https://api.odcloud.kr/api/15069309/v1/uddi:973ad0df-617a-4565-8e82-8ea7869e75d4'
## decode key가 적용되었음.
## api마다 연결이 되지 않는다고 한다면, encode, decode를 바꾸어 테스트해볼 것.
response = requests.get(url, headers=header_data, params=param_data)
response
# Out:
# <Response [200]>

# %%
json_data = response.json()#데이터탐색EDA:키가 몇개 있고 어던 내용인지 등 데이터를 보는거
json_data#키,벨류 형태로 딕셔너리로 되어있다.
# Out:
# {'currentCount': 10,
#  'data': [{'개체명(기업기관)': None,
#    '개체명(인물)': None,
#    '개체명(지역)': None,
#    '기고자': '당직자공용 기자',
#    '본문': "[헤럴드경제] '신종코로나' 확진환자 1명 추가됐다. 이로써 국내 확진환자는 총 12명이 됐다.   onlinenews",
#    '사건_사고 분류1': None,
#    '사건_사고 분류2': None,
#    '사건_사고 분류3': None,
#    '언론사': '헤럴드경제',
#    '원본주소': 'http://biz.heraldcorp.com/view.php?ud=20200201000027',
#    '일자': '2020-02-01',
#    '제목': "[속보] '신종코로나' 확진환자 1명 추가…12명으로 늘어",
#    '주소': 'http://www.bigkinds.or.kr/news/newsDetailView.do?newsId=02100701.20200201094636001',
#    '키워드': '신종코,추가,확진,환자,12명,신종코,추가,확진,환자,확진,12명',
#    '통합 분류1': '사회>의료_건강',
#    '통합 분류2': None,
#    '통합 분류3': None,
#    '특성추출': '신종코,추가,환자,확진'},
#   {'개체명(기업기관)': None,
#    '개체명(인물)': None,
#    '개체명(지역)': None,
#    '기고자': '이상규',
#    '본문': '[속보] 신종코로나 국내 12명 확진·70명 검사 중…접촉자 465명 감시 [디지털뉴스국 이상규 기자]',
#    '사건_사고 분류1': None,
#    '사건_사고 분류2': None,
#    '사건_사고 분류3': None,
#    '언론사': '매일경제',
# ...

# %%
import pickle #pickle은 파일을 저장할 목적으로 사용. 문서의 부가적인 정보까지(json성질,xml성질 등)저장. 서버에 파일 올려놓고 싶을 때.

# %%
with open('covid-gokr.json','wb') as fp:#지금사용하고 있는 작업폴더 위치에 파일 생성.
    pickle.dump(json_data,fp)
#w인데bite로 저장해야해서 wb라고 써야함.

#아래랑 같은 코드
#file.open('covid-gokr.json','wb'):
#file.close

# %%
with open('covid-gokr.json','rb') as fp:
    json_read_data=pickle.load(fp)#일반 텍스트 파일이 아닐때는 rb라고 b를 붙여준다.

# %%
type(json_read_data)#딕셔너리 타입이다.
# Out:
# dict

# %%
json_read_data
# Out:
# {'currentCount': 10,
#  'data': [{'개체명(기업기관)': None,
#    '개체명(인물)': None,
#    '개체명(지역)': None,
#    '기고자': '당직자공용 기자',
#    '본문': "[헤럴드경제] '신종코로나' 확진환자 1명 추가됐다. 이로써 국내 확진환자는 총 12명이 됐다.   onlinenews",
#    '사건_사고 분류1': None,
#    '사건_사고 분류2': None,
#    '사건_사고 분류3': None,
#    '언론사': '헤럴드경제',
#    '원본주소': 'http://biz.heraldcorp.com/view.php?ud=20200201000027',
#    '일자': '2020-02-01',
#    '제목': "[속보] '신종코로나' 확진환자 1명 추가…12명으로 늘어",
#    '주소': 'http://www.bigkinds.or.kr/news/newsDetailView.do?newsId=02100701.20200201094636001',
#    '키워드': '신종코,추가,확진,환자,12명,신종코,추가,확진,환자,확진,12명',
#    '통합 분류1': '사회>의료_건강',
#    '통합 분류2': None,
#    '통합 분류3': None,
#    '특성추출': '신종코,추가,환자,확진'},
#   {'개체명(기업기관)': None,
#    '개체명(인물)': None,
#    '개체명(지역)': None,
#    '기고자': '이상규',
#    '본문': '[속보] 신종코로나 국내 12명 확진·70명 검사 중…접촉자 465명 감시 [디지털뉴스국 이상규 기자]',
#    '사건_사고 분류1': None,
#    '사건_사고 분류2': None,
#    '사건_사고 분류3': None,
#    '언론사': '매일경제',
# ...

# %%
json_data
# Out:
# {'currentCount': 10,
#  'data': [{'개체명(기업기관)': None,
#    '개체명(인물)': None,
#    '개체명(지역)': None,
#    '기고자': '당직자공용 기자',
#    '본문': "[헤럴드경제] '신종코로나' 확진환자 1명 추가됐다. 이로써 국내 확진환자는 총 12명이 됐다.   onlinenews",
#    '사건_사고 분류1': None,
#    '사건_사고 분류2': None,
#    '사건_사고 분류3': None,
#    '언론사': '헤럴드경제',
#    '원본주소': 'http://biz.heraldcorp.com/view.php?ud=20200201000027',
#    '일자': '2020-02-01',
#    '제목': "[속보] '신종코로나' 확진환자 1명 추가…12명으로 늘어",
#    '주소': 'http://www.bigkinds.or.kr/news/newsDetailView.do?newsId=02100701.20200201094636001',
#    '키워드': '신종코,추가,확진,환자,12명,신종코,추가,확진,환자,확진,12명',
#    '통합 분류1': '사회>의료_건강',
#    '통합 분류2': None,
#    '통합 분류3': None,
#    '특성추출': '신종코,추가,환자,확진'},
#   {'개체명(기업기관)': None,
#    '개체명(인물)': None,
#    '개체명(지역)': None,
#    '기고자': '이상규',
#    '본문': '[속보] 신종코로나 국내 12명 확진·70명 검사 중…접촉자 465명 감시 [디지털뉴스국 이상규 기자]',
#    '사건_사고 분류1': None,
#    '사건_사고 분류2': None,
#    '사건_사고 분류3': None,
#    '언론사': '매일경제',
# ...

# %%
json_data['currentCount']
# Out:
# 10

# %%
 #"{'개체명(기업기관)': None,}"#file.write()하면 이렇게 제이슨을 스트링으로 만들어버림.

# %%
json_data['data']
# Out:
# [{'개체명(기업기관)': None,
#   '개체명(인물)': None,
#   '개체명(지역)': None,
#   '기고자': '당직자공용 기자',
#   '본문': "[헤럴드경제] '신종코로나' 확진환자 1명 추가됐다. 이로써 국내 확진환자는 총 12명이 됐다.   onlinenews",
#   '사건_사고 분류1': None,
#   '사건_사고 분류2': None,
#   '사건_사고 분류3': None,
#   '언론사': '헤럴드경제',
#   '원본주소': 'http://biz.heraldcorp.com/view.php?ud=20200201000027',
#   '일자': '2020-02-01',
#   '제목': "[속보] '신종코로나' 확진환자 1명 추가…12명으로 늘어",
#   '주소': 'http://www.bigkinds.or.kr/news/newsDetailView.do?newsId=02100701.20200201094636001',
#   '키워드': '신종코,추가,확진,환자,12명,신종코,추가,확진,환자,확진,12명',
#   '통합 분류1': '사회>의료_건강',
#   '통합 분류2': None,
#   '통합 분류3': None,
#   '특성추출': '신종코,추가,환자,확진'},
#  {'개체명(기업기관)': None,
#   '개체명(인물)': None,
#   '개체명(지역)': None,
#   '기고자': '이상규',
#   '본문': '[속보] 신종코로나 국내 12명 확진·70명 검사 중…접촉자 465명 감시 [디지털뉴스국 이상규 기자]',
#   '사건_사고 분류1': None,
#   '사건_사고 분류2': None,
#   '사건_사고 분류3': None,
#   '언론사': '매일경제',
#   '원본주소': 'http://news.mk.co.kr/newsRead.php?no=104142&year=2020',
#   '일자': '2020-02-01',
# ...

# %%
data_Values = json_data.get('data')#
data_Values
# Out:
# [{'개체명(기업기관)': None,
#   '개체명(인물)': None,
#   '개체명(지역)': None,
#   '기고자': '당직자공용 기자',
#   '본문': "[헤럴드경제] '신종코로나' 확진환자 1명 추가됐다. 이로써 국내 확진환자는 총 12명이 됐다.   onlinenews",
#   '사건_사고 분류1': None,
#   '사건_사고 분류2': None,
#   '사건_사고 분류3': None,
#   '언론사': '헤럴드경제',
#   '원본주소': 'http://biz.heraldcorp.com/view.php?ud=20200201000027',
#   '일자': '2020-02-01',
#   '제목': "[속보] '신종코로나' 확진환자 1명 추가…12명으로 늘어",
#   '주소': 'http://www.bigkinds.or.kr/news/newsDetailView.do?newsId=02100701.20200201094636001',
#   '키워드': '신종코,추가,확진,환자,12명,신종코,추가,확진,환자,확진,12명',
#   '통합 분류1': '사회>의료_건강',
#   '통합 분류2': None,
#   '통합 분류3': None,
#   '특성추출': '신종코,추가,환자,확진'},
#  {'개체명(기업기관)': None,
#   '개체명(인물)': None,
#   '개체명(지역)': None,
#   '기고자': '이상규',
#   '본문': '[속보] 신종코로나 국내 12명 확진·70명 검사 중…접촉자 465명 감시 [디지털뉴스국 이상규 기자]',
#   '사건_사고 분류1': None,
#   '사건_사고 분류2': None,
#   '사건_사고 분류3': None,
#   '언론사': '매일경제',
#   '원본주소': 'http://news.mk.co.kr/newsRead.php?no=104142&year=2020',
#   '일자': '2020-02-01',
# ...

# %%
type(data_Values)
# Out:
# list

# %%
print('신문기사 수>> ',len(data_Values))
# Out:
# 신문기사 수>>  10

# %%
data_Values[0]
# Out:
# {'개체명(기업기관)': None,
#  '개체명(인물)': None,
#  '개체명(지역)': None,
#  '기고자': '당직자공용 기자',
#  '본문': "[헤럴드경제] '신종코로나' 확진환자 1명 추가됐다. 이로써 국내 확진환자는 총 12명이 됐다.   onlinenews",
#  '사건_사고 분류1': None,
#  '사건_사고 분류2': None,
#  '사건_사고 분류3': None,
#  '언론사': '헤럴드경제',
#  '원본주소': 'http://biz.heraldcorp.com/view.php?ud=20200201000027',
#  '일자': '2020-02-01',
#  '제목': "[속보] '신종코로나' 확진환자 1명 추가…12명으로 늘어",
#  '주소': 'http://www.bigkinds.or.kr/news/newsDetailView.do?newsId=02100701.20200201094636001',
#  '키워드': '신종코,추가,확진,환자,12명,신종코,추가,확진,환자,확진,12명',
#  '통합 분류1': '사회>의료_건강',
#  '통합 분류2': None,
#  '통합 분류3': None,
#  '특성추출': '신종코,추가,환자,확진'}

# %%
com = data_Values[0]['언론사']#0번 인덱스에 키가 언론사인거
com
# Out:
# '헤럴드경제'

# %%
content = data_Values[0]['본문']
content
# Out:
# "[헤럴드경제] '신종코로나' 확진환자 1명 추가됐다. 이로써 국내 확진환자는 총 12명이 됐다.   onlinenews"

# %%
title = data_Values[0]['제목']
title
# Out:
# "[속보] '신종코로나' 확진환자 1명 추가…12명으로 늘어"

# %%
date = data_Values[0]['일자']
date
# Out:
# '2020-02-01'

# %%
field = data_Values[0]['통합 분류1']
field
# Out:
# '사회>의료_건강'

# %%
addr = data_Values[0]['주소']
addr
# Out:
# 'http://www.bigkinds.or.kr/news/newsDetailView.do?newsId=02100701.20200201094636001'

# %%
one_row = []

# %%
one_row.append(title)
one_row.append(content)
one_row.append(field)
one_row.append(date)
one_row.append(addr)
one_row.append(com)
one_row
# Out:
# ["[속보] '신종코로나' 확진환자 1명 추가…12명으로 늘어",
#  "[헤럴드경제] '신종코로나' 확진환자 1명 추가됐다. 이로써 국내 확진환자는 총 12명이 됐다.   onlinenews",
#  '사회>의료_건강',
#  '2020-02-01',
#  'http://www.bigkinds.or.kr/news/newsDetailView.do?newsId=02100701.20200201094636001',
#  '헤럴드경제']

# %%
total_row = []#리스트 안에 리스트를 넣어 1부터 10까지 해당 키워드 빼오는 방법
for no in range(10):
    title = data_Values[no]['제목']
    content = data_Values[no]['본문']
    field = data_Values[no]['통합 분류1']
    date = data_Values[no]['일자']
    addr = data_Values[no]['주소']
    com = data_Values[no]['언론사']
    one_row = []
    one_row.append(title)
    one_row.append(content)
    one_row.append(field)
    one_row.append(date)
    one_row.append(addr)
    one_row.append(com)
    
    print(one_row)
    total_row.append(one_row)
    total_row
# Out:
# ["[속보] '신종코로나' 확진환자 1명 추가…12명으로 늘어", "[헤럴드경제] '신종코로나' 확진환자 1명 추가됐다. 이로써 국내 확진환자는 총 12명이 됐다.   onlinenews", '사회>의료_건강', '2020-02-01', 'http://www.bigkinds.or.kr/news/newsDetailView.do?newsId=02100701.20200201094636001', '헤럴드경제']
# ['[속보] 신종코로나 국내 12명 확진·70명 검사 중…접촉자 465명 감시', '[속보] 신종코로나 국내 12명 확진·70명 검사 중…접촉자 465명 감시 [디지털뉴스국 이상규 기자]', '사회>의료_건강', '2020-02-01', 'http://www.bigkinds.or.kr/news/newsDetailView.do?newsId=02100101.20200201142733001', '매일경제']
# ['[속보] 신종 코로나 확진자 12명…70명 검사 중', '[그래픽=연합뉴스]  신종 코로나바이러스 확진자가 1일 오후 2시 현재 총 12명으로 확인됐다. 현재 검사 중인 사람은 총 70명이다. 황재희 기자 jhhwang', '사회>의료_건강', '2020-02-01', 'http://www.bigkinds.or.kr/news/newsDetailView.do?newsId=02100851.20200201135243001', '아주경제']
# ["[속보] '신종코로나' 확진환자 1명 추가돼 국내 총 12명…하루 새 6명 늘어", "[속보] '신종코로나' 확진환자…1명 추가 국내 총 12명   이미경 한경닷컴 기자 capital 기사제보 및 보도자료 open", '사회>의료_건강', '2020-02-01', 'http://www.bigkinds.or.kr/news/newsDetailView.do?newsId=02100601.20200201100004002', '한국경제']
# ...

# %%
with open('covid-sub-data.json','wb') as fp:
    pickle.dump(total_row,fp)

# %%
with open('covid-sub-data.json','rb') as fp:
    json_sub_data = pickle.load(fp)
json_sub_data
# Out:
# [["[속보] '신종코로나' 확진환자 1명 추가…12명으로 늘어",
#   "[헤럴드경제] '신종코로나' 확진환자 1명 추가됐다. 이로써 국내 확진환자는 총 12명이 됐다.   onlinenews",
#   '사회>의료_건강',
#   '2020-02-01',
#   'http://www.bigkinds.or.kr/news/newsDetailView.do?newsId=02100701.20200201094636001',
#   '헤럴드경제'],
#  ['[속보] 신종코로나 국내 12명 확진·70명 검사 중…접촉자 465명 감시',
#   '[속보] 신종코로나 국내 12명 확진·70명 검사 중…접촉자 465명 감시 [디지털뉴스국 이상규 기자]',
#   '사회>의료_건강',
#   '2020-02-01',
#   'http://www.bigkinds.or.kr/news/newsDetailView.do?newsId=02100101.20200201142733001',
#   '매일경제'],
#  ['[속보] 신종 코로나 확진자 12명…70명 검사 중',
#   '[그래픽=연합뉴스]  신종 코로나바이러스 확진자가 1일 오후 2시 현재 총 12명으로 확인됐다. 현재 검사 중인 사람은 총 70명이다. 황재희 기자 jhhwang',
#   '사회>의료_건강',
#   '2020-02-01',
#   'http://www.bigkinds.or.kr/news/newsDetailView.do?newsId=02100851.20200201135243001',
#   '아주경제'],
#  ["[속보] '신종코로나' 확진환자 1명 추가돼 국내 총 12명…하루 새 6명 늘어",
#   "[속보] '신종코로나' 확진환자…1명 추가 국내 총 12명   이미경 한경닷컴 기자 capital 기사제보 및 보도자료 open",
#   '사회>의료_건강',
#   '2020-02-01',
# ...

# %%
import pandas as pd
import numpy as np

# %%
with open('covid-sub-data-dic.json','wb') as fp:
    pickle.dump(data_Values,fp)

# %%
with open('covid-sub-data-dic.json','rb') as fp:
    json_sub_data_dic = pickle.load(fp)
json_sub_data_dic
#딕셔너리의 리스트
# Out:
# [{'개체명(기업기관)': None,
#   '개체명(인물)': None,
#   '개체명(지역)': None,
#   '기고자': '당직자공용 기자',
#   '본문': "[헤럴드경제] '신종코로나' 확진환자 1명 추가됐다. 이로써 국내 확진환자는 총 12명이 됐다.   onlinenews",
#   '사건_사고 분류1': None,
#   '사건_사고 분류2': None,
#   '사건_사고 분류3': None,
#   '언론사': '헤럴드경제',
#   '원본주소': 'http://biz.heraldcorp.com/view.php?ud=20200201000027',
#   '일자': '2020-02-01',
#   '제목': "[속보] '신종코로나' 확진환자 1명 추가…12명으로 늘어",
#   '주소': 'http://www.bigkinds.or.kr/news/newsDetailView.do?newsId=02100701.20200201094636001',
#   '키워드': '신종코,추가,확진,환자,12명,신종코,추가,확진,환자,확진,12명',
#   '통합 분류1': '사회>의료_건강',
#   '통합 분류2': None,
#   '통합 분류3': None,
#   '특성추출': '신종코,추가,환자,확진'},
#  {'개체명(기업기관)': None,
#   '개체명(인물)': None,
#   '개체명(지역)': None,
#   '기고자': '이상규',
#   '본문': '[속보] 신종코로나 국내 12명 확진·70명 검사 중…접촉자 465명 감시 [디지털뉴스국 이상규 기자]',
#   '사건_사고 분류1': None,
#   '사건_사고 분류2': None,
#   '사건_사고 분류3': None,
#   '언론사': '매일경제',
#   '원본주소': 'http://news.mk.co.kr/newsRead.php?no=104142&year=2020',
#   '일자': '2020-02-01',
# ...

# %%
df_test = pd.DataFrame(json_sub_data_dic)#[dic, dic, dic]은(딕셔너리의 리스트)를 데이터프레임으로 읽으면 아래와 같다.
df_test
# Out:
#   개체명(기업기관) 개체명(인물) 개체명(지역)            기고자  \
# 0      None    None    None       당직자공용 기자
# 1      None    None    None            이상규
# 2      None    None    None            황재희
# 3      None    None    None  이미경(capital);
# 4      None    None    None            김봄이
# 5      None    None    None        이정환2 기자
# 6      None    None    None            이상규
# 7      None    None    None            전동혁
# 8      None    None    None            조현의
# 9      None    None    None           None
#
#                                                   본문 사건_사고 분류1 사건_사고 분류2  \
# 0  [헤럴드경제] '신종코로나' 확진환자 1명 추가됐다. 이로써 국내 확진환자는 총 1...      None      None
# 1  [속보] 신종코로나 국내 12명 확진·70명 검사 중…접촉자 465명 감시 [디지털...      None      None
# 2  [그래픽=연합뉴스]  신종 코로나바이러스 확진자가 1일 오후 2시 현재 총 12명으...      None      None
# 3  [속보] '신종코로나' 확진환자…1명 추가 국내 총 12명   이미경 한경닷컴 기자...      None      None
# 4                        '신종코로나' 확진환자 1명 추가…국내 총 12명      None      None
# ...

# %%
df_test.info()#object라서 다 스트링인 것을 알  수 있따.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 18 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   개체명(기업기관)  0 non-null      object
#  1   개체명(인물)    0 non-null      object
#  2   개체명(지역)    0 non-null      object
#  3   기고자        9 non-null      object
#  4   본문         10 non-null     object
#  5   사건_사고 분류1  0 non-null      object
#  6   사건_사고 분류2  0 non-null      object
#  7   사건_사고 분류3  0 non-null      object
#  8   언론사        10 non-null     object
#  9   원본주소       9 non-null      object
#  10  일자         10 non-null     object
#  11  제목         10 non-null     object
#  12  주소         10 non-null     object
#  13  키워드        10 non-null     object
#  14  통합 분류1     10 non-null     object
#  15  통합 분류2     0 non-null      object
#  16  통합 분류3     0 non-null      object
#  17  특성추출       10 non-null     object
# dtypes: object(18)
# memory usage: 1.5+ KB

# %%
df_test.shape
# Out:
# (10, 18)

# %%
df_test.columns
# Out:
# Index(['개체명(기업기관)', '개체명(인물)', '개체명(지역)', '기고자', '본문', '사건_사고 분류1',
#        '사건_사고 분류2', '사건_사고 분류3', '언론사', '원본주소', '일자', '제목', '주소', '키워드',
#        '통합 분류1', '통합 분류2', '통합 분류3', '특성추출'],
#       dtype='object')

# %%
df_test.drop(columns=['개체명(기업기관)', '개체명(인물)', '개체명(지역)', '사건_사고 분류1', '사건_사고 분류2', '사건_사고 분류3',
                      '통합 분류2', '통합 분류3'],inplace=True)
df_test[:2]#2행까지만 찍어봄.
# Out:
#         기고자                                                 본문    언론사  \
# 0  당직자공용 기자  [헤럴드경제] '신종코로나' 확진환자 1명 추가됐다. 이로써 국내 확진환자는 총 1...  헤럴드경제
# 1       이상규  [속보] 신종코로나 국내 12명 확진·70명 검사 중…접촉자 465명 감시 [디지털...   매일경제
#
#                                                 원본주소          일자  \
# 0  http://biz.heraldcorp.com/view.php?ud=20200201...  2020-02-01
# 1  http://news.mk.co.kr/newsRead.php?no=104142&ye...  2020-02-01
#
#                                           제목  \
# 0           [속보] '신종코로나' 확진환자 1명 추가…12명으로 늘어
# 1  [속보] 신종코로나 국내 12명 확진·70명 검사 중…접촉자 465명 감시
#
#                                                   주소  \
# 0  http://www.bigkinds.or.kr/news/newsDetailView....
# 1  http://www.bigkinds.or.kr/news/newsDetailView....
#
#                                             키워드    통합 분류1                 특성추출
# 0          신종코,추가,확진,환자,12명,신종코,추가,확진,환자,확진,12명  사회>의료_건강         신종코,추가,환자,확진
# 1  신종코,확진,70명,검사,접촉자,감시,속보,신종코,확진,70명,검사,접촉자,감시  사회>의료_건강  접촉자,신종코,감시,확진,검사,속보

# %%
df_test['기고자'][:2]
# Out:
# 0    당직자공용 기자
# 1         이상규
# Name: 기고자, dtype: object

# %%
df_test['본문'][:2]
# Out:
# 0    [헤럴드경제] '신종코로나' 확진환자 1명 추가됐다. 이로써 국내 확진환자는 총 1...
# 1    [속보] 신종코로나 국내 12명 확진·70명 검사 중…접촉자 465명 감시 [디지털...
# Name: 본문, dtype: object

# %%
df_test.to_csv('covid_news.csv',encoding='utf8')#csv로 저장.(to_csv사용)

# %%
df_test2 = pd.read_csv('covid_news.csv',encoding='utf8')#읽어오기.
df_test2
# Out:
#    Unnamed: 0            기고자  \
# 0           0       당직자공용 기자
# 1           1            이상규
# 2           2            황재희
# 3           3  이미경(capital);
# 4           4            김봄이
# 5           5        이정환2 기자
# 6           6            이상규
# 7           7            전동혁
# 8           8            조현의
# 9           9            NaN
#
#                                                   본문    언론사  \
# 0  [헤럴드경제] '신종코로나' 확진환자 1명 추가됐다. 이로써 국내 확진환자는 총 1...  헤럴드경제
# 1  [속보] 신종코로나 국내 12명 확진·70명 검사 중…접촉자 465명 감시 [디지털...   매일경제
# 2  [그래픽=연합뉴스]  신종 코로나바이러스 확진자가 1일 오후 2시 현재 총 12명으...   아주경제
# 3  [속보] '신종코로나' 확진환자…1명 추가 국내 총 12명   이미경 한경닷컴 기자...   한국경제
# 4                        '신종코로나' 확진환자 1명 추가…국내 총 12명   매일신문
# 5      [헤럴드경제] 신종코로나 국내 12명 확진·70명은 검사 중…접촉자 465명 감시  헤럴드경제
# 6   [속보] '신종코로나' 확진환자 1명 추가…국내 총 12명 [디지털뉴스국 이상규 기자]   매일경제
# 7  ◀ 앵커 ..▶ .. ..국내에서 2차 감염에 이어 3차 감염자까지 나오면서 확진자...    MBC
# 8                       [아시아경제 조현의 기자]  조현의 기자 honey  아시아경제
# ...
