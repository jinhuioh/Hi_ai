# %%
#함수로 모듈화하기!!!
# 1.파일 함수로 모듈화해서 언제든지 함수호출해서 쓸 수 있게 
# 2.제목,글쓴이,이미지,별점 모두 함수로 모듈화

# %%
from urllib import request

# %%
from bs4 import BeautifulSoup

# %%
con = request.urlopen('https://novel.naver.com/webnovel/ranking?genre=101&periodType=DAILY')
con

# %%
con.status #status code
# Out:
# 200

# %%
doc = BeautifulSoup(con, 'html.parser')

# %%
 a_tag_list = doc.select('div.ranking_wrap_left span.author')
# a_tag_list = doc.select('span.author')
a_tag_list #content > div > div.ranking_lst > div.ranking_wrap_left > ul > li:nth-child(1) > a > div.info.v2 > p.sub_info > span.author
#content > div > div.ranking_lst > div.ranking_wrap_left > ul > li:nth-child(1) > a > div.info.v2 > p.sub_info > span.author
# Out:
# [<span class="author">놀마</span>,
#  <span class="author">꽃제이(진소예)</span>,
#  <span class="author">감사혜</span>,
#  <span class="author">달콤한홍차</span>,
#  <span class="author">핑크티</span>,
#  <span class="author">루시아</span>,
#  <span class="author">이도혜</span>,
#  <span class="author">칠칠마마</span>,
#  <span class="author">은율아</span>,
#  <span class="author">서한밤</span>,
#  <span class="author">이은비</span>,
#  <span class="author">미이라이</span>,
#  <span class="author">이달아</span>,
#  <span class="author">플아다</span>,
#  <span class="author">태소영</span>,
#  <span class="author">Lunar 이지연</span>,
#  <span class="author">빵양이</span>,
#  <span class="author">용감한 자매</span>,
#  <span class="author">탐이나</span>,
#  <span class="author">미래힐</span>,
#  <span class="author">로즈빈</span>,
#  <span class="author">주황연</span>,
#  <span class="author">트위티블리</span>,
#  <span class="author">진이현</span>,
#  <span class="author">셀리코</span>,
#  <span class="author">박수정(방울마마)</span>,
#  <span class="author">갓녀</span>,
#  <span class="author">이재익</span>,
#  <span class="author">플라비</span>,
#  <span class="author">반지영</span>,
#  <span class="author">최윤정(두잇)</span>,
#  <span class="author">달콤J</span>,
#  <span class="author">쥬시린시</span>,
#  <span class="author">노승아</span>,
#  <span class="author">플아다</span>,
#  <span class="author">태소영</span>,
#  <span class="author">플아다</span>,
#  <span class="author">성하</span>,
#  <span class="author">닥터냐냐</span>,
#  <span class="author">별규</span>,
#  <span class="author">배사비</span>,
#  <span class="author">이다홍</span>,
#  <span class="author">미니멜리사</span>,
#  <span class="author">이수안</span>,
#  <span class="author">래마</span>,
#  <span class="author">설우희</span>,
#  <span class="author">진저리</span>,
#  <span class="author">블랑드</span>,
#  <span class="author">이달리.</span>,
#  <span class="author">성소작</span>,
#  <span class="author">체리고</span>,
#  <span class="author">김결</span>,
#  <span class="author">플아다</span>,
#  <span class="author">갓녀</span>,
#  <span class="author">윤손</span>,
#  <span class="author">박수정(방울마마)</span>,
#  <span class="author">별규</span>,
#  <span class="author">이새인</span>,
#  <span class="author">이다홍</span>,
#  <span class="author">놀마</span>,
#  <span class="author">노승아</span>,
#  <span class="author">이범배</span>,
#  <span class="author">아라휘</span>,
#  <span class="author">주황연</span>,
#  <span class="author">이은비</span>,
#  <span class="author">안테</span>,
#  <span class="author">이은비</span>,
#  <span class="author">이 정</span>,
#  <span class="author">탐이나</span>,
#  <span class="author">Lunar 이지연</span>,
#  <span class="author">윤이수</span>,
#  <span class="author">용감한 자매</span>,
#  <span class="author">글쓰는 귀신</span>,
#  <span class="author">빵양이</span>,
#  <span class="author">핑크티</span>,
#  <span class="author">노승아</span>,
#  <span class="author">달콤J</span>,
#  <span class="author">파란드</span>,
#  <span class="author">노승아</span>,
#  <span class="author">이범배</span>,
#  <span class="author">주황연</span>,
#  <span class="author">안테</span>,
#  <span class="author">왕기대</span>,
#  <span class="author">이새인</span>,
#  <span class="author">벚꽃그리고</span>,
#  <span class="author">플아다</span>,
#  <span class="author">이은비</span>,
#  <span class="author">이른봄</span>,
#  <span class="author">탐이나</span>,
#  <span class="author">이경하</span>,
#  <span class="author">우지혜</span>,
#  <span class="author">별규</span>,
#  <span class="author">시니컬 앨리스</span>,
#  <span class="author">이달아</span>,
#  <span class="author">비연</span>,
#  <span class="author">은빈</span>,
#  <span class="author">달콤J</span>,
#  <span class="author">박수정(방울마마)</span>,
#  <span class="author">Lunar 이지연</span>,
#  <span class="author">로즈빈</span>]

# %%
len(a_tag_list)
# Out:
# 100

# %%
a_tag_list[0]
# Out:
# <span class="author">놀마</span>

# %%
for one in a_tag_list:
    print(one.text)
# Out:
# 놀마
# 꽃제이(진소예)
# 감사혜
# 달콤한홍차
# 핑크티
# 루시아
# 이도혜
# 칠칠마마
# 은율아
# 서한밤
# 이은비
# 미이라이
# 이달아
# 플아다
# 태소영
# Lunar 이지연
# 빵양이
# 용감한 자매
# 탐이나
# 미래힐
# 로즈빈
# 주황연
# 트위티블리
# 진이현
# 셀리코
# 박수정(방울마마)
# 갓녀
# 이재익
# 플라비
# 반지영
# 최윤정(두잇)
# 달콤J
# 쥬시린시
# 노승아
# 플아다
# 태소영
# 플아다
# 성하
# 닥터냐냐
# 별규
# 배사비
# 이다홍
# 미니멜리사
# 이수안
# 래마
# 설우희
# 진저리
# 블랑드
# 이달리.
# 성소작
# 체리고
# 김결
# 플아다
# 갓녀
# 윤손
# 박수정(방울마마)
# 별규
# 이새인
# 이다홍
# 놀마
# 노승아
# 이범배
# 아라휘
# 주황연
# 이은비
# 안테
# 이은비
# 이 정
# 탐이나
# Lunar 이지연
# 윤이수
# 용감한 자매
# 글쓰는 귀신
# 빵양이
# 핑크티
# 노승아
# 달콤J
# 파란드
# 노승아
# 이범배
# 주황연
# 안테
# 왕기대
# 이새인
# 벚꽃그리고
# 플아다
# 이은비
# 이른봄
# 탐이나
# 이경하
# 우지혜
# 별규
# 시니컬 앨리스
# 이달아
# 비연
# 은빈
# 달콤J
# 박수정(방울마마)
# Lunar 이지연
# 로즈빈

# %%
author_list = []

# %%
for one in a_tag_list:
    author_list.append(one.text)

# %%
author_list
# Out:
# ['놀마',
#  '꽃제이(진소예)',
#  '감사혜',
#  '달콤한홍차',
#  '핑크티',
#  '루시아',
#  '이도혜',
#  '칠칠마마',
#  '은율아',
#  '서한밤',
#  '이은비',
#  '미이라이',
#  '이달아',
#  '플아다',
#  '태소영',
#  'Lunar 이지연',
#  '빵양이',
#  '용감한 자매',
#  '탐이나',
#  '미래힐',
#  '로즈빈',
#  '주황연',
#  '트위티블리',
#  '진이현',
#  '셀리코',
#  '박수정(방울마마)',
#  '갓녀',
#  '이재익',
#  '플라비',
#  '반지영',
#  '최윤정(두잇)',
#  '달콤J',
#  '쥬시린시',
#  '노승아',
#  '플아다',
#  '태소영',
#  '플아다',
#  '성하',
#  '닥터냐냐',
#  '별규',
#  '배사비',
#  '이다홍',
#  '미니멜리사',
#  '이수안',
#  '래마',
#  '설우희',
#  '진저리',
#  '블랑드',
#  '이달리.',
#  '성소작',
#  '체리고',
#  '김결',
#  '플아다',
#  '갓녀',
#  '윤손',
#  '박수정(방울마마)',
#  '별규',
#  '이새인',
#  '이다홍',
#  '놀마',
#  '노승아',
#  '이범배',
#  '아라휘',
#  '주황연',
#  '이은비',
#  '안테',
#  '이은비',
#  '이 정',
#  '탐이나',
#  'Lunar 이지연',
#  '윤이수',
#  '용감한 자매',
#  '글쓰는 귀신',
#  '빵양이',
#  '핑크티',
#  '노승아',
#  '달콤J',
#  '파란드',
#  '노승아',
#  '이범배',
#  '주황연',
#  '안테',
#  '왕기대',
#  '이새인',
#  '벚꽃그리고',
#  '플아다',
#  '이은비',
#  '이른봄',
#  '탐이나',
#  '이경하',
#  '우지혜',
#  '별규',
#  '시니컬 앨리스',
#  '이달아',
#  '비연',
#  '은빈',
#  '달콤J',
#  '박수정(방울마마)',
#  'Lunar 이지연',
#  '로즈빈']

# %%
#별점 가져오기.

# %%
a_tag_list1 = doc.select('div.ranking_wrap_left span.score_area')
a_tag_list1#content > div > div.ranking_lst > div.ranking_wrap_left > ul > li:nth-child(1) > a > div.info.v2 > p.rating > span.score_area
# Out:
# [<span class="score_area"><span class="ico_star">별점</span>9.9</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.9</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.9</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.9</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.9</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.9</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.8</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.8</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.8</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.8</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.9</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.8</span>,
#  <span class="score_area"><span class="ico_star">별점</span>10.0</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.9</span>,
#  <span class="score_area"><span class="ico_star">별점</span>10.0</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.9</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.9</span>,
#  <span class="score_area"><span class="ico_star">별점</span>10.0</span>,
#  <span class="score_area"><span class="ico_star">별점</span>10.0</span>,
#  <span class="score_area"><span class="ico_star">별점</span>10.0</span>,
#  <span class="score_area"><span class="ico_star">별점</span>10.0</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.9</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.9</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.9</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.9</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.9</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.8</span>,
#  <span class="score_area"><span class="ico_star">별점</span>10.0</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.9</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.9</span>,
#  <span class="score_area"><span class="ico_star">별점</span>10.0</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.9</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.9</span>,
#  <span class="score_area"><span class="ico_star">별점</span>10.0</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.9</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.9</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.9</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.9</span>,
#  <span class="score_area"><span class="ico_star">별점</span>10.0</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.9</span>,
#  <span class="score_area"><span class="ico_star">별점</span>10.0</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.9</span>,
#  <span class="score_area"><span class="ico_star">별점</span>10.0</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.9</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.9</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.8</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.8</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.9</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.8</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.8</span>,
#  <span class="score_area"><span class="ico_star">별점</span>10.0</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.9</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.8</span>,
#  <span class="score_area"><span class="ico_star">별점</span>10.0</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.9</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.9</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.8</span>,
#  <span class="score_area"><span class="ico_star">별점</span>10.0</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.9</span>,
#  <span class="score_area"><span class="ico_star">별점</span>10.0</span>,
#  <span class="score_area"><span class="ico_star">별점</span>10.0</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.9</span>,
#  <span class="score_area"><span class="ico_star">별점</span>10.0</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.9</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.9</span>,
#  <span class="score_area"><span class="ico_star">별점</span>10.0</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.9</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.8</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.9</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.9</span>,
#  <span class="score_area"><span class="ico_star">별점</span>10.0</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.9</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.8</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.9</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.9</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.9</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.9</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.5</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.9</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.9</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.9</span>,
#  <span class="score_area"><span class="ico_star">별점</span>10.0</span>,
#  <span class="score_area"><span class="ico_star">별점</span>10.0</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.9</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.9</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.9</span>,
#  <span class="score_area"><span class="ico_star">별점</span>10.0</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.9</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.9</span>,
#  <span class="score_area"><span class="ico_star">별점</span>10.0</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.9</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.9</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.8</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.9</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.9</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.9</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.9</span>,
#  <span class="score_area"><span class="ico_star">별점</span>9.9</span>,
#  <span class="score_area"><span class="ico_star">별점</span>10.0</span>,
#  <span class="score_area"><span class="ico_star">별점</span>10.0</span>]

# %%
a_tag_list1[0]
# Out:
# <span class="score_area"><span class="ico_star">별점</span>9.9</span>

# %%
len(a_tag_list1)
# Out:
# 100

# %%
for one in a_tag_list1:
    print(one.text)
# Out:
# 별점9.9
# 별점9.9
# 별점9.9
# 별점9.9
# 별점9.9
# 별점9.9
# 별점9.8
# 별점9.8
# 별점9.8
# 별점9.8
# 별점9.9
# 별점9.8
# 별점10.0
# 별점9.9
# 별점10.0
# 별점9.9
# 별점9.9
# 별점10.0
# 별점10.0
# 별점10.0
# 별점10.0
# 별점9.9
# 별점9.9
# 별점9.9
# 별점9.9
# 별점9.9
# 별점9.8
# 별점10.0
# 별점9.9
# 별점9.9
# 별점10.0
# 별점9.9
# 별점9.9
# 별점10.0
# 별점9.9
# 별점9.9
# 별점9.9
# 별점9.9
# 별점10.0
# 별점9.9
# 별점10.0
# 별점9.9
# 별점10.0
# 별점9.9
# 별점9.9
# 별점9.8
# 별점9.8
# 별점9.9
# 별점9.8
# 별점9.8
# 별점10.0
# 별점9.9
# 별점9.8
# 별점10.0
# 별점9.9
# 별점9.9
# 별점9.8
# 별점10.0
# 별점9.9
# 별점10.0
# 별점10.0
# 별점9.9
# 별점10.0
# 별점9.9
# 별점9.9
# 별점10.0
# 별점9.9
# 별점9.8
# 별점9.9
# 별점9.9
# 별점10.0
# 별점9.9
# 별점9.8
# 별점9.9
# 별점9.9
# 별점9.9
# 별점9.9
# 별점9.5
# 별점9.9
# 별점9.9
# 별점9.9
# 별점10.0
# 별점10.0
# 별점9.9
# 별점9.9
# 별점9.9
# 별점10.0
# 별점9.9
# 별점9.9
# 별점10.0
# 별점9.9
# 별점9.9
# 별점9.8
# 별점9.9
# 별점9.9
# 별점9.9
# 별점9.9
# 별점9.9
# 별점10.0
# 별점10.0

# %%
free_star_list = []

# %%
for i in range(0, len(a_tag_list1), 1):
    a = a_tag_list1[i].text.replace('별점','')
    print(a)
    free_star_list.append(a)
# Out:
# 9.9
# 9.9
# 9.9
# 9.9
# 9.9
# 9.9
# 9.8
# 9.8
# 9.8
# 9.8
# 9.9
# 9.8
# 10.0
# 9.9
# 10.0
# 9.9
# 9.9
# 10.0
# 10.0
# 10.0
# 10.0
# 9.9
# 9.9
# 9.9
# 9.9
# 9.9
# 9.8
# 10.0
# 9.9
# 9.9
# 10.0
# 9.9
# 9.9
# 10.0
# 9.9
# 9.9
# 9.9
# 9.9
# 10.0
# 9.9
# 10.0
# 9.9
# 10.0
# 9.9
# 9.9
# 9.8
# 9.8
# 9.9
# 9.8
# 9.8
# 10.0
# 9.9
# 9.8
# 10.0
# 9.9
# 9.9
# 9.8
# 10.0
# 9.9
# 10.0
# 10.0
# 9.9
# 10.0
# 9.9
# 9.9
# 10.0
# 9.9
# 9.8
# 9.9
JPEG/320%2B320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20180427_243/novel_1524812318523gqvfc_JPEG/Untitled-3.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20201229_111/novel_1609239358626HeXfi_JPEG/320%2B320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20190328_150/novel_1553750458550RfKKS_JPEG/320%2B320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20200831_135/novel_1598874238512cY2u4_JPEG/320%2B320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20200630_95/novel_1593512932969FEND0_JPEG/3202B320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20150828_281/novel_14407368771801NvDy_JPEG/320%2B320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20191231_143/novel_1577777498654X2WjX_JPEG/3202B320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20170228_12/novel_1488271933489lAKQW_JPEG/320%2B320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20200729_190/novel_159601589965047YhX_JPEG/3202B320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20191030_87/novel_1572419511859PitHV_JPEG/320%2B320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20190531_230/novel_1559296249045W0HPC_JPEG/320%2B320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20200831_284/novel_1598874075845Ed5Vg_JPEG/320%2B320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20170921_297/novel_1505977902925US7uL_JPEG/320%2B320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20200203_147/novel_1580717890614BnB86_JPEG/3202B320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20160201_213/novel_1454294749664LtPk0_JPEG/320%2B320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20151026_193/novel_1445821989149HPJh9_JPEG/320%2B320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20161128_154/novel_1480318930251HlQIG_JPEG/320%2B320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20180829_175/novel_1535537542419n0CHj_JPEG/320%2B320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20200330_168/novel_1585562733481qdISc_JPEG/3202B320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20201127_56/novel_1606473150416LaWOz_JPEG/320%2B320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20150720_21/novel_1437385142651a6OEq_JPEG/EBB295EB8C80EBA19CEC82ACEB9E91ED9598EB9DBC.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20150720_265/novel_1437385449639pIhr2_JPEG/EC9B90ED9598EB8A94EAB1B4EB8488ED9598EB8298.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20201127_265/novel_1606473321584nRwHn_JPEG/320%2B320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20181030_172/novel_1540892926302aFT8i_JPEG/320%2B320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20210127_85/novel_16117421045591Vk5D_JPEG/320%2B320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20190830_110/novel_1567148103000wWFGk_JPEG/320%2B320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20150804_240/novel_14386798199524R3Gq_JPEG/320%2B320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20171030_189/novel_1509332060484lHQeE_JPEG/320%2B320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20200729_289/novel_1596016465224hJes6_JPEG/3202B320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20201029_60/novel_1603976052969MIBQA_JPEG/320%2B320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20160225_97/novel_1456392086584TxO9o_JPEG/320%2B320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20180725_210/novel_1532488560101MCH82_JPEG/320%2B320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20160330_33/novel_1459321578250pwwam_JPEG/320%2B320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20171129_274/novel_1511946237248djiyt_JPEG/320%2B320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20160201_231/novel_1454294616092evHGV_JPEG/320%2B320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20210428_228/novel_1619587982189ePz95_JPEG/320%2B320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20200330_34/novel_1585562347413aiS8V_JPEG/3202B320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20200925_1/novel_1601019682470Nj9AP_JPEG/320%2B320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20180528_180/novel_1527495453466cm0j1_JPEG/320%2B320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20180427_123/novel_1524811887100tygz0_JPEG/320320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20150713_145/novel_1436786452876vcT65_JPEG/EC8B9CEB8B88ECBBACED99A9ED9B84.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20171010_46/novel_1507598935089LxwGU_JPEG/320%2B320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20190927_56/novel_1569573092637TwkO2_JPEG/320%2B320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20171129_36/novel_1511946957825V2oAU_JPEG/320%2B320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20170628_268/novel_1498627968670wsmHa_JPEG/320%2B320.jpg?type=f150_118_2']

# %%
#함수로 모듈화.........어떻게 하는걸까?????매개변수에 무엇을 넣어야하는지 어디까지 함수안에 묶어야 하는지 1도 모르겠다.

# %%
def title(free_title,free_title_list):

# %%
    free_title=doc.select( 'div.ranking_lst > div.ranking_wrap_left span.tit' )

# %%
    free_title_list=[]

# %%
    for i in range(0, len(free_title), 1):

        a= free_title[i].text
        aa =a.replace(',',' ')
        free_title_list.append(aa)

    free_title_list

# %%
def file(webnovel_file):
    
    webnovel_file = open('webnovel1.csv', 'a', encoding="UTF-8-sig")

# %%
    for i in range(100):
        file.write(author_list[i] + ',' +
                             free_star_list[i] + ',' +
                              img_list[i] + ',' +
                              free_title_list[i]
                            +'\n')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15268/1702775497.py in <module>
#       1 for i in range(100):
# ----> 2     file.write(author_list[i] + ',' +
#       3                          free_star_list[i] + ',' +
#       4                           img_list[i] + ',' +
#       5                           free_title_list[i]
#
# AttributeError: 'function' object has no attribute 'write'

# %%
webnovel_file.close()

# %%
import pandas as pd

# %%
novel = pd.read_csv('webnovel1.csv', encoding='utf8')
novel
