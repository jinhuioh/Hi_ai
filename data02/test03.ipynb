# %%
import pandas as pd#데이터분석할때 필요!
import numpy as np#수치계산할때 씀
import seaborn as sns#시각화 라이브러리seaborn 시각화 할 때 사용

# %%
df = sns.load_dataset("titanic")
df.head(6)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
# 5         0       3    male   NaN      0      0   8.4583        Q  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# 5    man        True  NaN   Queenstown    no   True

# %%
# 나이가 30살 이상 남자 승객 조건 필터링
# fare를 많이 낸 순서로 내림차순 정렬
# 상위 10개를 출력

# %%
df["sex"][df["sex"]=='male']
# Out:
# 0      male
# 4      male
# 5      male
# 6      male
# 7      male
#        ...
# 883    male
# 884    male
# 886    male
# 889    male
# 890    male
# Name: sex, Length: 577, dtype: object

# %%
# 나이가 20살 이상 40살 미만인 승객
# pclass가 1등급 혹은 2등급인 승객
# 열(column)은 survived, pclass, age, fare 만 나오게 출력
# 10개만 출력

# sample['name'].isin(['kim', 'lee'])
# sample.isin(['kim', 'lee'])
# condition = sample['name'].isin(['kim', 'lee'])
# sample.loc[condition]

# %%
# sample['name'].isin(['kim', 'lee'])
# sample.isin(['kim', 'lee'])
# condition = sample['name'].isin(['kim', 'lee'])
# sample.loc[condition]
# df1['VIP'] = True
# df1.drop(1) : 행삭제
# df1.drop(df1.index[0:10])
# df1.drop(df1.index[[1, 3, 5, 7, 9]])
# df1.drop('class', axis=1) ==> df1.drop('class', 1)
# df1.drop(['who', 'deck', 'alive'], axis=1)
# df1.drop(['who', 'deck', 'alive'], axis=1, inplace=True)
# df1 = df.copy()
# df1['round'] = round(df1['fare'] / df1['age'], 2)

# %%
df[df['age'] >= 30]['age'].value_counts().head()
# Out:
# 30.0    25
# 36.0    22
# 35.0    18
# 32.0    18
# 31.0    17
# Name: age, dtype: int64

# %%
df.sort_values(by='fare', ascending=False).head(10)
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 258         1       1  female  35.0      0      0  512.3292        C  First
# 737         1       1    male  35.0      0      0  512.3292        C  First
# 679         1       1    male  36.0      0      1  512.3292        C  First
# 88          1       1  female  23.0      3      2  263.0000        S  First
# 27          0       1    male  19.0      3      2  263.0000        S  First
# 341         1       1  female  24.0      3      2  263.0000        S  First
# 438         0       1    male  64.0      1      4  263.0000        S  First
# 311         1       1  female  18.0      2      2  262.3750        C  First
# 742         1       1  female  21.0      2      2  262.3750        C  First
# 118         0       1    male  24.0      0      1  247.5208        C  First
#
#        who  adult_male deck  embark_town alive  alone
# 258  woman       False  NaN    Cherbourg   yes   True
# ...

# %%
result1 = df.sort_values(by='fare', ascending=False).head(10)
result1
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 258         1       1  female  35.0      0      0  512.3292        C  First
# 737         1       1    male  35.0      0      0  512.3292        C  First
# 679         1       1    male  36.0      0      1  512.3292        C  First
# 88          1       1  female  23.0      3      2  263.0000        S  First
# 27          0       1    male  19.0      3      2  263.0000        S  First
# 341         1       1  female  24.0      3      2  263.0000        S  First
# 438         0       1    male  64.0      1      4  263.0000        S  First
# 311         1       1  female  18.0      2      2  262.3750        C  First
# 742         1       1  female  21.0      2      2  262.3750        C  First
# 118         0       1    male  24.0      0      1  247.5208        C  First
#
#        who  adult_male deck  embark_town alive  alone
# 258  woman       False  NaN    Cherbourg   yes   True
# ...

# %%
result1.sort_index(ascending=False)
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 742         1       1  female  21.0      2      2  262.3750        C  First
# 737         1       1    male  35.0      0      0  512.3292        C  First
# 679         1       1    male  36.0      0      1  512.3292        C  First
# 438         0       1    male  64.0      1      4  263.0000        S  First
# 341         1       1  female  24.0      3      2  263.0000        S  First
# 311         1       1  female  18.0      2      2  262.3750        C  First
# 258         1       1  female  35.0      0      0  512.3292        C  First
# 118         0       1    male  24.0      0      1  247.5208        C  First
# 88          1       1  female  23.0      3      2  263.0000        S  First
# 27          0       1    male  19.0      3      2  263.0000        S  First
#
#        who  adult_male deck  embark_town alive  alone
# 742  woman       False    B    Cherbourg   yes  False
# ...

# %%
# 나이가 20살 이상 40살 미만인 승객
# pclass가 1등급 혹은 2등급인 승객
# 열(column)은 survived, pclass, age, fare 만 나오게 출력
# 10개만 출력
df[(df['age'] >= 20) & (df['age'] < 40)]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
result2 = df[df['pclass'].isin([1, 2])]  #df[df['pclass'] < 3]
result2
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 6           0       1    male  54.0      0      0  51.8625        S   First
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# 11          1       1  female  58.0      0      0  26.5500        S   First
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 883         0       2    male  28.0      0      0  10.5000        S  Second
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df[df['pclass'].isin([1, 2])][['survived', 'pclass', 'age', 'fare']][:5]
#pclass가 1또는 2인 값 중에 'survived', 'pclass', 'age', 'fare' 컬럼을 추출
# Out:
#     survived  pclass   age     fare
# 1          1       1  38.0  71.2833
# 3          1       1  35.0  53.1000
# 6          0       1  54.0  51.8625
# 9          1       2  14.0  30.0708
# 11         1       1  58.0  26.5500

# %%
result2[['survived', 'pclass', 'age', 'fare']]#'survived', 'pclass', 'age', 'fare'컬럼을 출력
# Out:
#      survived  pclass   age     fare
# 1           1       1  38.0  71.2833
# 3           1       1  35.0  53.1000
# 6           0       1  54.0  51.8625
# 9           1       2  14.0  30.0708
# 11          1       1  58.0  26.5500
# ..        ...     ...   ...      ...
# 880         1       2  25.0  26.0000
# 883         0       2  28.0  10.5000
# 886         0       2  27.0  13.0000
# 887         1       1  19.0  30.0000
# 889         1       1  26.0  30.0000
#
# [400 rows x 4 columns]

# %%
df.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
# 나이가 30살 이상 승객
# pclass가 1등급 혹은 2등급인 승객
# 열(column)은 survived, pclass, age, fare 만 나오게 출력
# 10개만 출력

# %%
result3 =df[df['age']>=30]#결과가 데이터프레임Dataframe
result3
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 4           0       3    male  35.0      0      0   8.0500        S  Third
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 11          1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 873         0       3    male  47.0      0      0   9.0000        S  Third
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 881         0       3    male  33.0      0      0   7.8958        S  Third
# 885         0       3  female  39.0      0      5  29.1250        Q  Third
# 890         0       3    male  32.0      0      0   7.7500        Q  Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# 1.나이가 30살 이상 남자 승객 조건 필터링
# 2.fare를 많이 낸 순서로 내림차순 정렬
# 3.상위 10개를 출력
#pd.to_datetime(df[컬럼명]):pd.to_datatime(Series객체)#컬럼명의 데이터타입은 시리즈객체이다.

# %%
df[df['age']>=30]['age']#age가 30이상인거.에서 age컬럼을 프린트
# Out:
# 1      38.0
# 3      35.0
# 4      35.0
# 6      54.0
# 11     58.0
#        ...
# 873    47.0
# 879    56.0
# 881    33.0
# 885    39.0
# 890    32.0
# Name: age, Length: 330, dtype: float64

# %%
df[df['age']>=30]['age'].value_counts().head()#값들을 나이에 따라 카운트하고 상위 5개 프린트
# Out:
# 30.0    25
# 36.0    22
# 35.0    18
# 32.0    18
# 31.0    17
# Name: age, dtype: int64

# %%
result_pclass = df[df['pclass'].isin([1, 2])].head(8)  #이즈인isin에 1,2와 일치하는 pclass값만 추출
result_pclass
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 11         1       1  female  58.0      0      0  26.5500        S   First
# 15         1       2  female  55.0      0      0  16.0000        S  Second
# 17         1       2    male   NaN      0      0  13.0000        S  Second
# 20         0       2    male  35.0      0      0  26.0000        S  Second
#
#       who  adult_male deck  embark_town alive  alone
# 1   woman       False    C    Cherbourg   yes  False
# 3   woman       False    C  Southampton   yes  False
# 6     man        True    E  Southampton    no   True
# 9   child       False  NaN    Cherbourg   yes  False
# ...

# %%
#df.sort_index() #오름차순 작은---->큰거
#df.sort_index(ascending = True)가 디폴트 값
#내림차순으로 하려면 False로 바꿔주면 된다.

# %%
df.sort_index()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# 1. 나이가 30살 이상 남자 승객 조건 필터링
condition1 = (df['age'] >= 30)
condition2 = (df['who'] == 'man')
df.loc[condition1 & condition2]
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked   class  \
# 4           0       3  male  35.0      0      0   8.0500        S   Third
# 6           0       1  male  54.0      0      0  51.8625        S   First
# 13          0       3  male  39.0      1      5  31.2750        S   Third
# 20          0       2  male  35.0      0      0  26.0000        S  Second
# 21          1       2  male  34.0      0      0  13.0000        S  Second
# ..        ...     ...   ...   ...    ...    ...      ...      ...     ...
# 867         0       1  male  31.0      0      0  50.4958        S   First
# 872         0       1  male  33.0      0      0   5.0000        S   First
# 873         0       3  male  47.0      0      0   9.0000        S   Third
# 881         0       3  male  33.0      0      0   7.8958        S   Third
# 890         0       3  male  32.0      0      0   7.7500        Q   Third
#
#      who  adult_male deck  embark_town alive  alone
# ...

# %%
df.count()
# Out:
# survived       891
# pclass         891
# sex            891
# age            714
# sibsp          891
# parch          891
# fare           891
# embarked       889
# class          891
# who            891
# adult_male     891
# deck           203
# embark_town    889
# alive          891
# alone          891
# dtype: int64
